# %%
import json
import pandas as pd
pd.options.mode.chained_assignment = None
from tqdm import tqdm
import numpy as np
import regex as re
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
import pandas as pd

from sklearn.metrics.pairwise import cosine_similarity, paired_distances
import numpy as np
np.random.seed(0)

from tqdm import tqdm
import random

# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set_theme(style="white", palette="pastel")
import scipy
import json

from scipy import sparse

import time
import gc

# %%
data_dir = '2022-06-02'

# %%
papers = pd.read_csv(f'scibert_encoded_papers/valid_metadata_{data_dir}.csv',sep='\t').set_index('cord_uid')[['title','journal','publish_time']].sort_values('publish_time')

# %%
jrnls = Counter(papers['journal']).most_common(100)

# %%
Counter(papers['journal']).most_common()
# Out:
# [('Int J Environ Res Public Health', 5242),
#  ('PLoS One', 2954),
#  ('Cureus', 1908),
#  ('Sci Rep', 1898),
#  ('Front Psychol', 1815),
#  ('BMJ Open', 1672),
#  ('Front Immunol', 1402),
#  ('Front Public Health', 1377),
#  ('Int J Mol Sci', 1338),
#  ('J Clin Med', 1291),
#  ('Vaccines (Basel)', 1281),
#  ('Viruses', 1270),
#  ('J Med Virol', 1001),
#  ('BMC Public Health', 858),
#  ('Sensors (Basel)', 856),
#  ('Healthcare (Basel)', 813),
#  ('Nutrients', 813),
#  ('Front Med (Lausanne)', 758),
#  ('Front Psychiatry', 736),
#  ('Molecules', 639),
#  ('Environ Sci Pollut Res Int', 627),
#  ('medRxiv', 608),
#  ('BMC Health Serv Res', 522),
#  ('Front Pharmacol', 502),
#  ('J Med Internet Res', 495),
#  ('Front Microbiol', 490),
#  ('Diagnostics (Basel)', 490),
#  ('JAMA Netw Open', 468),
#  ('BMC Infect Dis', 444),
#  ('MMWR Morb Mortal Wkly Rep', 443),
#  ('bioRxiv', 441),
#  ('BMJ Glob Health', 438),
#  ('Cells', 431),
#  ('Nat Commun', 420),
#  ('Heliyon', 419),
#  ('Trials', 376),
#  ('J Infect', 376),
#  ('Pathogens', 357),
#  ('Cancers (Basel)', 357),
#  ('J Family Med Prim Care', 350),
#  ('Vaccine', 340),
#  ('Microorganisms', 330),
#  ('Biomedicines', 328),
#  ('J Gen Intern Med', 321),
#  ('BMC Med Educ', 320),
#  ('Clin Case Rep', 315),
#  ('Lancet', 313),
#  ('Ann Med Surg (Lond)', 310),
#  ('Front Pediatr', 301),
#  ('Front Cell Infect Microbiol', 300),
#  ('Antibiotics (Basel)', 300),
#  ('Foods', 299),
#  ('Pharmaceutics', 296),
#  ('JMIR Form Res', 295),
#  ('Medicina (Kaunas)', 288),
#  ('Proc Natl Acad Sci U S A', 280),
#  ('J Pers Med', 280),
#  ('Int J Infect Dis', 276),
#  ('Medicine (Baltimore)', 276),
#  ('Clin Microbiol Infect', 275),
#  ('Children (Basel)', 273),
#  ('Curr Psychol', 269),
#  ('Emerg Infect Dis', 263),
#  ('Int J Clin Pract', 260),
#  ('Animals (Basel)', 257),
#  ('Pharmaceuticals (Basel)', 253),
#  ('Crit Care', 247),
#  ('Pan Afr Med J', 246),
#  ('JMIR Res Protoc', 246),
#  ('Front Cardiovasc Med', 232),
#  ('Med Hypotheses', 231),
#  ('Indian J Ophthalmol', 230),
#  ('Front Neurol', 230),
#  ('Educ Inf Technol (Dordr)', 223),
#  ('BMJ Case Rep', 222),
#  ('Open Forum Infect Dis', 219),
#  ('Am J Infect Control', 217),
#  ('J Eur Acad Dermatol Venereol', 213),
#  ('Dermatol Ther', 212),
#  ('Brain Sci', 209),
#  ('EClinicalMedicine', 208),
#  ('Risk Manag Healthc Policy', 207),
#  ('Life (Basel)', 203),
#  ('Biomolecules', 202),
#  ('Comput Biol Med', 199),
#  ('Front Vet Sci', 198),
#  ('Br J Surg', 197),
#  ('Indian J Crit Care Med', 193),
#  ('Front Cell Dev Biol', 192),
#  ('Front Oncol', 190),
#  ('J Affect Disord', 187),
#  ('Polymers (Basel)', 187),
#  ('Euro Surveill', 186),
#  ('BMC Geriatr', 186),
#  ('Front Nutr', 184),
#  ('J Infect Public Health', 182),
#  ('Front Physiol', 181),
#  ('Disaster medicine and public health preparedness', 180),
#  ('Neurol Sci', 180),
#  ('BMC Psychiatry', 176),
#  ('Environ Res', 176),
#  ('EBioMedicine', 175),
#  ('Biology (Basel)', 173),
#  ('Psychiatry Res', 172),
#  ('N Engl J Med', 169),
#  ('Materials (Basel)', 169),
#  ('mBio', 168),
#  ('Acta Biomed', 164),
#  ('Biomed Res Int', 163),
#  ('ACS Omega', 163),
#  ('Int J Gynaecol Obstet', 162),
#  ('Front Mol Biosci', 162),
#  ('Entropy (Basel)', 161),
#  ('J Hosp Infect', 160),
#  ('PeerJ', 160),
#  ('Am J Emerg Med', 160),
#  ('Antioxidants (Basel)', 160),
#  ('Lancet Infect Dis', 158),
#  ('Front Genet', 157),
#  ('PLoS Pathog', 156),
#  ('Asian J Psychiatr', 154),
#  ('Int J Gen Med', 153),
#  ('J Am Geriatr Soc', 151),
#  ('Ir J Med Sci', 151),
#  ('Prev Med Rep', 150),
#  ('J Am Coll Emerg Physicians Open', 150),
#  ('Nanomaterials (Basel)', 148),
#  ('JMIR Public Health Surveill', 148),
#  ('PLoS Negl Trop Dis', 148),
#  ('Soc Sci Med', 146),
#  ('Multimed Tools Appl', 145),
#  ('J Korean Med Sci', 143),
#  ('Infect Drug Resist', 143),
#  ('Front Endocrinol (Lausanne)', 142),
#  ('BMC Pregnancy Childbirth', 142),
#  ('Med J Aust', 140),
#  ('J Clin Virol', 139),
#  ('Crit Care Explor', 139),
#  ('Support Care Cancer', 138),
#  ('Infection control and hospital epidemiology', 137),
#  ('Biosensors (Basel)', 137),
#  ('Radiol Case Rep', 137),
#  ('J Multidiscip Healthc', 135),
#  ('Infection', 134),
#  ('Health Sci Rep', 134),
#  ('Lancet Reg Health Eur', 132),
#  ('Clin Infect Dis', 131),
#  ('Am J Trop Med Hyg', 131),
#  ('Am J Transplant', 130),
#  ('Med Sci Educ', 130),
#  ('Br Dent J', 129),
#  ('J Racial Ethn Health Disparities', 129),
#  ('Int J Surg', 128),
#  ('J Public Health (Oxf)', 127),
#  ('Nucleic Acids Res', 126),
#  ('RSC advances', 126),
#  ('CMAJ', 126),
#  ('Travel Med Infect Dis', 125),
#  ('Data Brief', 125),
#  ('Eur Respir J', 124),
#  ('Mult Scler Relat Disord', 124),
#  ('J Educ Health Promot', 124),
#  ('Influenza Other Respir Viruses', 123),
#  ('Eye (Lond)', 123),
#  ('Epidemiol Infect', 123),
#  ('J Prim Care Community Health', 123),
#  ('J Clin Lab Anal', 122),
#  ('J Fungi (Basel)', 122),
#  ('Br J Anaesth', 121),
#  ('BMJ', 121),
#  ('J Healthc Eng', 120),
#  ('Front Bioeng Biotechnol', 120),
#  ('Rev Med Virol', 119),
#  ('Ann Oper Res', 119),
#  ('Sci Adv', 118),
#  ('China CDC Wkly', 118),
#  ('J Card Surg', 118),
#  ('World J Clin Cases', 118),
#  ('Br J Haematol', 117),
#  ('Chaos Solitons Fractals', 116),
#  ('Signal Transduct Target Ther', 116),
#  ('JMIR Mhealth Uhealth', 116),
#  ('Int J Health Plann Manage', 115),
#  ('BMJ Open Qual', 115),
#  ('Sci Total Environ', 114),
#  ('PLoS Med', 114),
#  ('Biosens Bioelectron', 114),
#  ('Diabetes Metab Syndr', 114),
#  ('Front Digit Health', 114),
#  ('Virol J', 113),
#  ('Lancet Respir Med', 113),
#  ('Global Health', 113),
#  ('Lancet Reg Health West Pac', 113),
#  ('Intern Emerg Med', 112),
#  ('Plants (Basel)', 112),
#  ('Nurs Open', 112),
#  ('Comput Intell Neurosci', 112),
#  ('Int J Dermatol', 110),
#  ('J Virol Methods', 110),
#  ('Acta Paediatr', 109),
#  ('Inquiry', 108),
#  ('BMC Med', 108),
#  ('eLife', 108),
#  ('Pediatr Blood Cancer', 108),
#  ('Infect Control Hosp Epidemiol', 108),
#  ('J Am Heart Assoc', 107),
#  ('Journal of global health', 107),
#  ('PLoS Comput Biol', 107),
#  ('Behav Sci (Basel)', 107),
#  ('Neural Comput Appl', 107),
#  ('Pediatr Pulmonol', 106),
#  ('Front Sociol', 106),
#  ('IDCases', 105),
#  ('iScience', 104),
#  ('Int Immunopharmacol', 104),
#  ('Int J Surg Case Rep', 103),
#  ('Kidney Int Rep', 102),
#  ('Ann Intern Med', 102),
#  ('Pharmacy (Basel)', 102),
#  ('J Relig Health', 102),
#  ('Front Sports Act Living', 102),
#  ('J Neurol', 102),
#  ('Indian J Pediatr', 101),
#  ('J Biol Chem', 101),
#  ('BMC Med Inform Decis Mak', 101),
#  ('BMC Nurs', 101),
#  ('AIDS Behav', 100),
#  ('Microbiol Spectr', 100),
#  ('Transfusion', 99),
#  ('Intensive Care Med', 98),
#  ('SSM Popul Health', 98),
#  ('Intern Med J', 98),
#  ('Trop Med Infect Dis', 97),
#  ('Am J Case Rep', 97),
#  ('Anal Bioanal Chem', 97),
#  ('Eur J Intern Med', 96),
#  ('J Pediatr', 96),
#  ('Int J Ment Health Addict', 96),
#  ('Arch Public Health', 96),
#  ('Lancet Reg Health Am', 96),
#  ('J Paediatr Child Health', 95),
#  ('Acad Psychiatry', 95),
#  ('Evid Based Complement Alternat Med', 95),
#  ('Head Neck', 94),
#  ('J Int AIDS Soc', 94),
#  ('Environ Dev Sustain', 94),
#  ('Int J Equity Health', 93),
#  ('JCI insight', 93),
#  ('Diagn Microbiol Infect Dis', 92),
#  ('J Cardiothorac Vasc Anesth', 92),
#  ('Biomed Pharmacother', 92),
#  ('ESC Heart Fail', 92),
#  ('BMC Pediatr', 91),
#  ('J Infect Dis', 91),
#  ('Allergy', 91),
#  ('Genes (Basel)', 91),
#  ('J Med Case Rep', 91),
#  ('J Virol', 90),
#  ('Eur Arch Otorhinolaryngol', 90),
#  ('BMC Pulm Med', 90),
#  ('JMIR Ment Health', 89),
#  ('Transpl Infect Dis', 89),
#  ('Results Phys', 89),
#  ('Res Pract Thromb Haemost', 88),
#  ('Pilot Feasibility Stud', 88),
#  ('Human vaccines & immunotherapeutics', 87),
#  ('J Cosmet Dermatol', 87),
#  ('Sustain Cities Soc', 87),
#  ('Financ Res Lett', 87),
#  ('SN Comput Sci', 87),
#  ('Transbound Emerg Dis', 86),
#  ('Brain Behav Immun', 86),
#  ('Eur J Cancer', 86),
#  ('Ann Surg Oncol', 86),
#  ('Kidney Int', 86),
#  ('Micromachines (Basel)', 85),
#  ('Nat Rev Immunol', 85),
#  ('SN Compr Clin Med', 85),
#  ('Psychol Res Behav Manag', 85),
#  ('Curr Oncol', 85),
#  ('Pak J Med Sci', 84),
#  ('Infect Dis Poverty', 84),
#  ('Eur J Pediatr', 84),
#  ('Digit Health', 84),
#  ('Indian J Otolaryngol Head Neck Surg', 84),
#  ('Adv Med Educ Pract', 84),
#  ('F1000Res', 83),
#  ('Acad Radiol', 83),
#  ('ERJ Open Res', 83),
#  ('Pers Individ Dif', 83),
#  ('Iran J Public Health', 83),
#  ('JMIR Med Inform', 83),
#  ('Clin Rheumatol', 82),
#  ('J Patient Exp', 82),
#  ('Stem Cell Res Ther', 82),
#  ('Glob Health Sci Pract', 82),
#  ('Patient Prefer Adherence', 82),
#  ('Comput Struct Biotechnol J', 82),
#  ('Arch Virol', 81),
#  ('Anaesthesia', 81),
#  ('Environ Pollut', 81),
#  ('J Clin Microbiol', 81),
#  ('IEEE Access', 81),
#  ('J Psychiatr Res', 81),
#  ('Eur J Clin Invest', 80),
#  ('Health Res Policy Syst', 80),
#  ('Front Chem', 79),
#  ('Lancet Glob Health', 79),
#  ('Int J Public Health', 79),
#  ('Can J Anaesth', 78),
#  ('J Transl Med', 78),
#  ('Clin Epidemiol Glob Health', 78),
#  ('BMC Res Notes', 78),
#  ('Disaster Med Public Health Prep', 78),
#  ('Obes Surg', 78),
#  ('Res Sq', 78),
#  ('Soft comput', 78),
#  ('Malar J', 78),
#  ('Immun Inflamm Dis', 77),
#  ('Aging (Albany NY)', 77),
#  ('J Stroke Cerebrovasc Dis', 77),
#  ('Inform Med Unlocked', 77),
#  ('Respir Res', 77),
#  ('BJPsych Open', 77),
#  ('Front Neurosci', 77),
#  ('Microbiology spectrum', 77),
#  ('J Thromb Haemost', 76),
#  ('Crit Care Med', 76),
#  ('JNMA J Nepal Med Assoc', 76),
#  ('Can J Public Health', 76),
#  ('SAGE Open Med', 76),
#  ('Clin Transl Med', 75),
#  ('J Autism Dev Disord', 75),
#  ('J Plast Reconstr Aesthet Surg', 75),
#  ('BMC Oral Health', 75),
#  ('BMC Fam Pract', 74),
#  ('Lancet Rheumatol', 74),
#  ('J Occup Environ Med', 74),
#  ('Bundesgesundheitsblatt Gesundheitsforschung Gesundheitsschutz', 74),
#  ('Eur J Neurol', 73),
#  ('Pediatr Infect Dis J', 73),
#  ('J Inflamm Res', 73),
#  ('One Health', 72),
#  ('Heart Lung', 72),
#  ('J Cell Mol Med', 72),
#  ('Respir Med Case Rep', 72),
#  ('Infect Dis Ther', 72),
#  ('Am J Respir Crit Care Med', 72),
#  ('Bull World Health Organ', 72),
#  ('Rheumatol Int', 72),
#  ('Harm Reduct J', 72),
#  ('World J Gastroenterol', 72),
#  ('Ann Intensive Care', 71),
#  ('Adv Sci (Weinh)', 71),
#  ('Commun Biol', 71),
#  ('Hum Resour Health', 70),
#  ('Health Expect', 70),
#  ('J Adolesc Health', 70),
#  ('Rev Francoph Lab', 70),
#  ('J Intern Med', 70),
#  ('J Nurs Manag', 70),
#  ('Rev Esp Quimioter', 70),
#  ('NPJ Digit Med', 70),
#  ('Brain Behav', 70),
#  ('Clin Ophthalmol', 70),
#  ('BMC Med Res Methodol', 70),
#  ('Clin Transl Immunology', 69),
#  ('Indian J Anaesth', 69),
#  ('GMS J Med Educ', 69),
#  ('Brain Behav Immun Health', 69),
#  ('Eur Heart J Case Rep', 69),
#  ('Emerg Microbes Infect', 68),
#  ('NPJ Vaccines', 68),
#  ('Rev Panam Salud Publica', 68),
#  ('Mol Biol Rep', 68),
#  ('Front Glob Womens Health', 68),
#  ('Pediatr Res', 67),
#  ('J Clin Nurs', 67),
#  ('Adv Radiat Oncol', 67),
#  ('Dela J Public Health', 67),
#  ('Acad Med', 67),
#  ('Oral Dis', 67),
#  ('Ital J Pediatr', 67),
#  ('BMC Nephrol', 67),
#  ('J Infect Chemother', 66),
#  ('J Adv Nurs', 66),
#  ('Mar Drugs', 66),
#  ('Comput Math Methods Med', 66),
#  ('BMC Psychol', 66),
#  ('BMC Vet Res', 65),
#  ('Med Sci Monit', 65),
#  ('Sleep Med', 65),
#  ('BMC Med Ethics', 65),
#  ('J Dent Educ', 65),
#  ('J Public Aff', 65),
#  ('Eur Radiol', 64),
#  ('Antimicrob Resist Infect Control', 64),
#  ('Infect Dis Model', 64),
#  ('Am J Med', 64),
#  ('Am J Hematol', 64),
#  ('J Hepatol', 64),
#  ('Int J Disaster Risk Reduct', 64),
#  ('Clin Exp Dermatol', 64),
#  ('Saudi J Biol Sci', 64),
#  ('Emerging microbes & infections', 64),
#  ('Membranes (Basel)', 64),
#  ('Public Health Pract (Oxf)', 64),
#  ('Ecol Evol', 63),
#  ('J Pain Symptom Manage', 63),
#  ('Phys Fluids (1994)', 63),
#  ('Int J Lab Hematol', 63),
#  ('Scientometrics', 63),
#  ('SN Soc Sci', 63),
#  ('Virus Res', 62),
#  ('Hum Vaccin Immunother', 62),
#  ('Sustain Sci', 62),
#  ('Build Environ', 61),
#  ('West J Emerg Med', 61),
#  ('J Crit Care', 61),
#  ('Med J Armed Forces India', 61),
#  ('Thromb Res', 61),
#  ('Clin Transl Sci', 61),
#  ('J Cancer Educ', 61),
#  ('J Community Health', 61),
#  ('Plast Reconstr Surg Glob Open', 61),
#  ('Front Aging Neurosci', 61),
#  ('Infect Genet Evol', 60),
#  ('BMJ Open Respir Res', 60),
#  ('Clin Imaging', 60),
#  ('Mater Today Proc', 60),
#  ('J Ambient Intell Humaniz Comput', 60),
#  ('Intern Med', 60),
#  ('Adv Ther', 60),
#  ('MedEdPORTAL : the journal of teaching and learning resources', 60),
#  ('Chest', 59),
#  ('Infect Dis Rep', 59),
#  ('Laryngoscope', 59),
#  ('Turk J Med Sci', 59),
#  ('BMC Musculoskelet Disord', 59),
#  ('Ann Vasc Surg', 59),
#  ('Nature', 59),
#  ('Metabolites', 59),
#  ('Brief Bioinform', 59),
#  ('Educ Technol Res Dev', 59),
#  ('Orphanet J Rare Dis', 59),
#  ('Eur J Nucl Med Mol Imaging', 58),
#  ('Int J Antimicrob Agents', 58),
#  ('Radiother Oncol', 58),
#  ('Ann Indian Acad Neurol', 58),
#  ('Clin Immunol', 58),
#  ('Respirology', 58),
#  ('Technol Forecast Soc Change', 58),
#  ('Wellcome Open Res', 58),
#  ('Med Clin (Engl Ed)', 58),
#  ('J Surg Oncol', 58),
#  ('J Mol Struct', 58),
#  ('Arquivos brasileiros de cardiologia', 58),
#  ('J Clin Immunol', 58),
#  ('J Travel Med', 57),
#  ('Int J Prev Med', 57),
#  ('Arch Bronconeumol', 57),
#  ('Reprod Health', 57),
#  ('Am J Otolaryngol', 57),
#  ('J Endocrinol Invest', 57),
#  ('Respirol Case Rep', 57),
#  ('J Public Health Res', 57),
#  ('Saudi Pharm J', 57),
#  ('Matern Child Health J', 57),
#  ('Cancer Med', 57),
#  ('Surg Endosc', 57),
#  ('J Community Psychol', 57),
#  ('Dig Dis Sci', 56),
#  ('J Thromb Thrombolysis', 56),
#  ('Am J Med Sci', 56),
#  ('J Bus Ethics', 56),
#  ('Aging Clin Exp Res', 56),
#  ('Clinics (Sao Paulo)', 56),
#  ('Global health action', 56),
#  ('Front Surg', 56),
#  ('Internet Interv', 56),
#  ('Respir Med', 55),
#  ('Indian J Surg', 55),
#  ('Phytother Res', 55),
#  ('Soc Indic Res', 55),
#  ('BMC Neurol', 55),
#  ('Transplantation', 55),
#  ('JMIR Hum Factors', 55),
#  ('Royal Society open science', 55),
#  ('Int J Biol Macromol', 54),
#  ('J Nutr Health Aging', 54),
#  ('Am J Geriatr Psychiatry', 54),
#  ('Br J Clin Pharmacol', 54),
#  ('Perspect Psychiatr Care', 54),
#  ('Clin Appl Thromb Hemost', 54),
#  ('BMC Bioinformatics', 54),
#  ('PeerJ Comput Sci', 54),
#  ('Science advances', 54),
#  ('Virol Sin', 53),
#  ('Eur Heart J', 53),
#  ('World Neurosurg', 53),
#  ('Bull Acad Natl Med', 53),
#  ('Exp Ther Med', 53),
#  ('Drug Alcohol Depend', 53),
#  ('GeoJournal', 53),
#  ('Wien Klin Wochenschr', 53),
#  ('Am J Cardiol', 53),
#  ('Nonlinear Dyn', 53),
#  ('J Glob Health', 53),
#  ('Syst Rev', 53),
#  ('BMC Palliat Care', 53),
#  ('Journal of microbiology & biology education', 53),
#  ('Antiviral Res', 52),
#  ('Front Plant Sci', 52),
#  ('High Educ (Dordr)', 52),
#  ('Eur J Obstet Gynecol Reprod Biol', 52),
#  ('Laryngoscope Investig Otolaryngol', 52),
#  ('Clin Pharmacol Ther', 52),
#  ('J Pharm Policy Pract', 52),
#  ('J Clean Prod', 52),
#  ('European journal of psychotraumatology', 52),
#  ('BMJ Paediatr Open', 52),
#  ('Confl Health', 52),
#  ('Transl Psychiatry', 52),
#  ('BMC Womens Health', 52),
#  ('Z Gesundh Wiss', 51),
#  ('Trop Med Health', 51),
#  ('Dig Liver Dis', 51),
#  ('ANZ J Surg', 51),
#  ('J Vasc Surg', 51),
#  ('J Urban Health', 51),
#  ('J Exp Med', 51),
#  ('eLife (Cambridge)', 51),
#  ('QJM', 50),
#  ('J Am Med Inform Assoc', 50),
#  ('Isr J Health Policy Res', 50),
#  ('Appl Soft Comput', 50),
#  ('Cancer', 50),
#  ('BMC Cancer', 50),
#  ('Medical education online', 50),
#  ('Inf Syst Front', 50),
#  ('J Investig Med High Impact Case Rep', 50),
#  ('J Int Med Res', 50),
#  ('Pediatr Nephrol', 50),
#  ('Front Hum Neurosci', 50),
#  ('JMIR Med Educ', 50),
#  ('Environ Monit Assess', 49),
#  ('Oxid Med Cell Longev', 49),
#  ('Expert Syst Appl', 49),
#  ('Eur Child Adolesc Psychiatry', 49),
#  ('Health Technol (Berl)', 49),
#  ('Sci Educ (Dordr)', 49),
#  ('RMD Open', 49),
#  ('Comput Human Behav', 49),
#  ('Implement Sci Commun', 49),
#  ('J Nephrol', 49),
#  ('Lancet Microbe', 49),
#  ('J Med Chem', 48),
#  ('AI Soc', 48),
#  ('CJEM', 48),
#  ('J Ultrasound Med', 48),
#  ('Int J Cardiol', 48),
#  ('JACC Case Rep', 48),
#  ('Eur J Public Health', 48),
#  ('Res Involv Engagem', 48),
#  ('Ambio', 48),
#  ('J Prev Med Hyg', 48),
#  ('J Eat Disord', 48),
#  ('BMC Prim Care', 48),
#  ('mSphere', 47),
#  ('Oncologist', 47),
#  ('Resuscitation', 47),
#  ('Toxins (Basel)', 47),
#  ('Int J Radiat Oncol Biol Phys', 47),
#  ('Pediatr Radiol', 47),
#  ('Clin Kidney J', 47),
#  ('Eur J Investig Health Psychol Educ', 47),
#  ('Front Robot AI', 47),
#  ('Appl Microbiol Biotechnol', 46),
#  ('Cell Rep', 46),
#  ('Eur J Case Rep Intern Med', 46),
#  ('Diabetes Res Clin Pract', 46),
#  ('Transfus Apher Sci', 46),
#  ('J Bus Res', 46),
#  ('JCO Glob Oncol', 46),
#  ('Front Artif Intell', 46),
#  ('JMIR Pediatr Parent', 46),
#  ('Indian J Palliat Care', 46),
#  ('Community Ment Health J', 46),
#  ('J Fam Violence', 46),
#  ('Eur J Med Res', 46),
#  ('J Immigr Minor Health', 46),
#  ('Arab J Sci Eng', 46),
#  ('BMC Emerg Med', 46),
#  ('Annals of the American Thoracic Society', 46),
#  ('J Migr Health', 45),
#  ('FASEB J', 45),
#  ('Radiology', 45),
#  ('Public Health', 45),
#  ('Theranostics', 45),
#  ('Anaesthesist', 45),
#  ('Med Klin Intensivmed Notfmed', 45),
#  ('Ecancermedicalscience', 45),
#  ('J Perinatol', 45),
#  ('Pulmonology', 45),
#  ('Catheter Cardiovasc Interv', 45),
#  ('JAMIA Open', 45),
#  ('Anesth Analg', 45),
#  ('EMBO Mol Med', 45),
#  ('Cities', 45),
#  ('Front Res Metr Anal', 45),
#  ('Mil Med', 45),
#  ('Child Abuse Negl', 45),
#  ('J Bioeth Inq', 45),
#  ('Health Soc Care Community', 45),
#  ('Journal of virology', 45),
#  ('Graefes Arch Clin Exp Ophthalmol', 44),
#  ('Aliment Pharmacol Ther', 44),
#  ('Surgery', 44),
#  ('Health Policy', 44),
#  ('Journal of clinical and translational science', 44),
#  ('Bone Jt Open', 44),
#  ('Annals of global health', 44),
#  ('Indian J Psychol Med', 44),
#  ('Am J Ophthalmol Case Rep', 44),
#  ('BMC Cardiovasc Disord', 44),
#  ('Physiol Rep', 44),
#  ('J Nanobiotechnology', 43),
#  ('Cell Mol Immunol', 43),
#  ('Eur J Immunol', 43),
#  ('Environ Chem Lett', 43),
#  ('Endocrine', 43),
#  ('TechTrends', 43),
#  ('Bone Marrow Transplant', 43),
#  ('Clin Cardiol', 43),
#  ('Qual Quant', 43),
#  ('BMJ Health Care Inform', 43),
#  ('Chemical science', 43),
#  ('Geohealth', 43),
#  ('Early Child Educ J', 43),
#  ('Bull Natl Res Cent', 43),
#  ('Soc Psychiatry Psychiatr Epidemiol', 43),
#  ('Gerontol Geriatr Med', 43),
#  ('Virology', 42),
#  ('Pharmacol Res', 42),
#  ('Microb Biotechnol', 42),
#  ('Kidney Med', 42),
#  ('J Surg Case Rep', 42),
#  ('Indoor Air', 42),
#  ('Ann Allergy Asthma Immunol', 42),
#  ('Agric Human Values', 42),
#  ('Future virology', 42),
#  ('Int Nurs Rev', 42),
#  ('Curr Cardiol Rep', 42),
#  ('Prev Med', 42),
#  ('Can Med Educ J', 42),
#  ('Diabetes Ther', 42),
#  ('Clim Change', 42),
#  ('Nat Hazards (Dordr)', 42),
#  ('Eur Phys J Plus', 42),
#  ('Health Promot Int', 42),
#  ('Nat Med', 41),
#  ('Virulence', 41),
#  ('Biochem Biophys Res Commun', 41),
#  ('Biomed J', 41),
#  ('World J Surg', 41),
#  ('Intensive Crit Care Nurs', 41),
#  ('Biochem Mol Biol Educ', 41),
#  ('mSystems', 41),
#  ('JAAD Case Rep', 41),
#  ('Stem Cell Rev Rep', 41),
#  ('J Neurol Sci', 41),
#  ('Int J Drug Policy', 41),
#  ('Age Ageing', 41),
#  ('Eur J Health Econ', 41),
#  ('Br J Dermatol', 41),
#  ('Afr J Prim Health Care Fam Med', 41),
#  ('Contemp Clin Trials Commun', 41),
#  ('Acta Neurol Belg', 41),
#  ('Sci Data', 41),
#  ('Health Policy Plan', 41),
#  ('J Affect Disord Rep', 41),
#  ('J Child Fam Stud', 41),
#  ('SAGE Open Med Case Rep', 41),
#  ('Explor Res Clin Soc Pharm', 41),
#  ('CMAJ Open', 41),
#  ('American journal of respiratory and critical care medicine', 41),
#  ('Commun Med (Lond)', 41),
#  ('Health Policy Technol', 40),
#  ('Talanta', 40),
#  ('Can J Cardiol', 40),
#  ('BJGP open', 40),
#  ('Transp Policy (Oxf)', 40),
#  ('Public Health Nurs', 40),
#  ('Z Rheumatol', 40),
#  ('J Clin Neurosci', 40),
#  ('Behav Anal Pract', 40),
#  ('J Occup Health', 40),
#  ('Indian J Psychiatry', 40),
#  ('J Chem Inf Model', 40),
#  ('Epidemiol Health', 40),
#  ('J Cancer Surviv', 40),
#  ('Anal Chem', 40),
#  ('Stud Russ Econ Dev', 40),
#  ('Cogn Res Princ Implic', 40),
#  ('Osong Public Health Res Perspect', 39),
#  ('Adv Differ Equ', 39),
#  ('R Soc Open Sci', 39),
#  ('Lancet Public Health', 39),
#  ('Indian J Community Med', 39),
#  ('Aging Dis', 39),
#  ('J Pediatr Nurs', 39),
#  ('J Res Med Sci', 39),
#  ('Geriatr Nurs', 39),
#  ('Int Wound J', 39),
#  ('Cell Rep Med', 39),
#  ('J Ayurveda Integr Med', 39),
#  ('J Hazard Mater', 39),
#  ('Patterns (N Y)', 39),
#  ('Pharmacol Res Perspect', 39),
#  ('J Public Health Policy', 39),
#  ('J Med Educ Curric Dev', 39),
#  ('Transl Vis Sci Technol', 39),
#  ('Int J Chron Obstruct Pulmon Dis', 39),
#  ('Pediatr Qual Saf', 39),
#  ('SN Bus Econ', 39),
#  ('Mikrochim Acta', 39),
#  ('Insights Imaging', 39),
#  ('Vox Sang', 38),
#  ('Nervenarzt', 38),
#  ('Br J Oral Maxillofac Surg', 38),
#  ('Health Equity', 38),
#  ('BMC Genomics', 38),
#  ('Metabolism', 38),
#  ('Pediatr Neurol', 38),
#  ('Int J Med Inform', 38),
#  ('Ann Epidemiol', 38),
#  ('Am J Surg', 38),
#  ('Eur Geriatr Med', 38),
#  ('BMC Complement Med Ther', 38),
#  ('Int J Obes (Lond)', 38),
#  ('Neuropsychiatr Dis Treat', 38),
#  ('Rheumatology (Oxford)', 38),
#  ('Chin Med J (Engl)', 38),
#  ('Vaccine X', 38),
#  ('J Epidemiol Community Health', 38),
#  ('Mindfulness (N Y)', 38),
#  ('Epidemics', 38),
#  ('Indian J Med Res', 37),
#  ('Cell Mol Life Sci', 37),
#  ('Microb Pathog', 37),
#  ('Eur J Clin Microbiol Infect Dis', 37),
#  ('Drug Discov Today', 37),
#  ('Vet Sci', 37),
#  ('Nat Rev Nephrol', 37),
#  ('Int J Ment Health Nurs', 37),
#  ('Endosc Int Open', 37),
#  ('Matern Child Nutr', 37),
#  ('Ann Hematol', 37),
#  ('Transplant Direct', 37),
#  ('J Supercomput', 37),
#  ('Int J Cardiol Heart Vasc', 37),
#  ('J Med Syst', 37),
#  ('Appl Psychol Health Well Being', 37),
#  ('Biomed Signal Process Control', 37),
#  ('Bioengineered', 37),
#  ('Lung India', 37),
#  ('Mol Divers', 37),
#  ('Ther Innov Regul Sci', 37),
#  ('Transp Res Interdiscip Perspect', 37),
#  ('Sens Actuators B Chem', 36),
#  ('Eur J Med Chem', 36),
#  ('BMC Anesthesiol', 36),
#  ('Virus Evol', 36),
#  ('Am J Clin Pathol', 36),
#  ('J Epidemiol Glob Health', 36),
#  ('Chin Med', 36),
#  ('Mov Disord', 36),
#  ('Ann Clin Transl Neurol', 36),
#  ('Ann Neurol', 36),
#  ('J Surg Res', 36),
#  ('Chem Eng J', 36),
#  ('Arch Sex Behav', 36),
#  ('Med Lav', 36),
#  ('Toxics', 36),
#  ('Int Urogynecol J', 36),
#  ('J Technol Behav Sci', 36),
#  ('Int J Environ Sci Technol (Tehran)', 36),
#  ('Nurs Rep', 36),
#  ('Qual Life Res', 36),
#  ('Development (Rome)', 36),
#  ('Int J Educ Technol High Educ', 36),
#  ('J Bras Pneumol', 35),
#  ('Cell Death Dis', 35),
#  ('Microbes Infect', 35),
#  ('Res Social Adm Pharm', 35),
#  ('Risk Anal', 35),
#  ('ESMO Open', 35),
#  ('PLoS Biol', 35),
#  ('Aten Primaria', 35),
#  ('Virusdisease', 35),
#  ('Liver Int', 35),
#  ('Ann Surg', 35),
#  ('Eur Neuropsychopharmacol', 35),
#  ('Urology', 35),
#  ('Geriatrics (Basel)', 35),
#  ('Child Youth Serv Rev', 35),
#  ('Int Arch Occup Environ Health', 35),
#  ('ACR Open Rheumatol', 35),
#  ('JGH Open', 35),
#  ('Neurol Neuroimmunol Neuroinflamm', 35),
#  ('Int Orthop', 35),
#  ('Her Russ Acad Sci', 35),
#  ('EJHaem', 35),
#  ('Food Secur', 35),
#  ('Int J Behav Nutr Phys Act', 35),
#  ('JMIR Aging', 35),
#  ('BMC Ophthalmol', 35),
#  ('J Clin Epidemiol', 35),
#  ('Eur Phys J Spec Top', 35),
#  ('Acad Pediatr', 34),
#  ('Revista da Sociedade Brasileira de Medicina Tropical', 34),
#  ('Int J Epidemiol', 34),
#  ('EMBO Rep', 34),
#  ('J Am Coll Cardiol', 34),
#  ('Surg Neurol Int', 34),
#  ('Malays J Med Sci', 34),
#  ('Acute Med Surg', 34),
#  ('MMW Fortschr Med', 34),
#  ('Mycoses', 34),
#  ('Bioinformatics', 34),
#  ('J Pain Res', 34),
#  ('Health Qual Life Outcomes', 34),
#  ('Gend Work Organ', 34),
#  ('Angew Chem Int Ed Engl', 34),
#  ('J Med Ethics', 34),
#  ('Emerg Radiol', 34),
#  ('Arq Bras Cardiol', 34),
#  ('JAC Antimicrob Resist', 34),
#  ('Br J Cancer', 34),
#  ('Alzheimers Dement (N Y)', 34),
#  ('J Taibah Univ Med Sci', 34),
#  ('BMJ Open Sport Exerc Med', 34),
#  ('JMA J', 34),
#  ('Womens Health (Lond)', 34),
#  ('Soc Sci Humanit Open', 34),
#  ('Int J Nanomedicine', 33),
#  ('An Pediatr (Engl Ed)', 33),
#  ('Infect Dis Health', 33),
#  ('Int Forum Allergy Rhinol', 33),
#  ('Muscle Nerve', 33),
#  ('Internist (Berl)', 33),
#  ('Curr Probl Cardiol', 33),
#  ('Dent J (Basel)', 33),
#  ('Front Cell Neurosci', 33),
#  ('Transpl Int', 33),
#  ('J Sleep Res', 33),
#  ('S Afr Fam Pract (2004)', 33),
#  ('J Glob Infect Dis', 33),
#  ('Cell Biosci', 33),
#  ('Disabil Health J', 33),
#  ('Clin Oral Investig', 33),
#  ('PharmacoEcon Outcomes News', 33),
#  ('Infect Chemother', 33),
#  ('Aust N Z J Public Health', 33),
#  ('GeroScience', 33),
#  ('Geophys Res Lett', 33),
#  ('Inflammopharmacology', 33),
#  ('Int J Geriatr Psychiatry', 33),
#  ('Clean Technol Environ Policy', 33),
#  ('Air Qual Atmos Health', 33),
#  ('J Immunother Cancer', 33),
#  ('J Cardiovasc Dev Dis', 33),
#  ('Trans R Soc Trop Med Hyg', 33),
#  ('Addict Sci Clin Pract', 33),
#  ('Appl Intell (Dordr)', 33),
#  ('Clin Exp Vaccine Res', 32),
#  ('Comput Methods Programs Biomed', 32),
#  ('Anaesth Crit Care Pain Med', 32),
#  ('Pediatr Allergy Immunol', 32),
#  ('Diabetes Metab Syndr Obes', 32),
#  ('Microbiol Resour Announc', 32),
#  ('Monatsschr Kinderheilkd', 32),
#  ('Clin Dermatol', 32),
#  ('Int J Mol Med', 32),
#  ('Photodiagnosis Photodyn Ther', 32),
#  ('J Allergy Clin Immunol Pract', 32),
#  ('Respir Investig', 32),
#  ('EXCLI J', 32),
#  ('Clin Neurol Neurosurg', 32),
#  ('J Acoust Soc Am', 32),
#  ('AIMS Public Health', 32),
#  ('Epilepsy Behav', 32),
#  ('J Gen Fam Med', 32),
#  ('Ann Am Thorac Soc', 32),
#  ('J Obstet Gynaecol Res', 32),
#  ('J Leukoc Biol', 32),
#  ('World Dev', 32),
#  ('Prev Chronic Dis', 32),
#  ('Curr Psychiatry Rep', 32),
#  ('Prim Health Care Res Dev', 32),
#  ('Acta Anaesthesiol Scand', 32),
#  ('Arch Gynecol Obstet', 32),
#  ('Thromb J', 32),
#  ('BMC Gastroenterol', 32),
#  ('Fam Pract', 32),
#  ('J Pharm Bioallied Sci', 32),
#  ('Annals of medicine', 32),
#  ('Drug Deliv Transl Res', 32),
#  ('Appl Intell', 32),
#  ('Sex Res Social Policy', 32),
#  ('JMIR Serious Games', 32),
#  ('Sci Afr', 32),
#  ('BMC Sports Sci Med Rehabil', 32),
#  ('Egypt J Neurol Psychiatr Neurosurg', 32),
#  ('Braz J Infect Dis', 31),
#  ('Vet Res', 31),
#  ('Nat Rev Gastroenterol Hepatol', 31),
#  ('Br J Health Psychol', 31),
#  ('Glob Health Res Policy', 31),
#  ('Eur J Heart Fail', 31),
#  ('FASEB Bioadv', 31),
#  ('J Frailty Aging', 31),
#  ('World J Urol', 31),
#  ('Notf Rett Med', 31),
#  ('Am J Physiol Lung Cell Mol Physiol', 31),
#  ('Mediterr J Hematol Infect Dis', 31),
#  ('Palliat Med', 31),
#  ('BJOG', 31),
#  ('J Clin Hypertens (Greenwich)', 31),
#  ('Rev Clin Esp (Barc)', 31),
#  ('Western Pac Surveill Response J', 31),
#  ('Child Psychiatry Hum Dev', 31),
#  ('J Fam Econ Issues', 31),
#  ('Med Health Care Philos', 31),
#  ('Int Ophthalmol', 31),
#  ('J Big Data', 31),
#  ('South Med J', 31),
#  ('Clin Transplant', 31),
#  ('J Med Life', 30),
#  ('Lancet Psychiatry', 30),
#  ('World J Pediatr', 30),
#  ('Indian J Tuberc', 30),
#  ('J Heart Lung Transplant', 30),
#  ('Redox Biol', 30),
#  ('J Mol Diagn', 30),
#  ('Int J Nurs Stud', 30),
#  ('Acad Emerg Med', 30),
#  ('Echocardiography', 30),
#  ('Oman Med J', 30),
#  ('Life Sci', 30),
#  ('Leukemia', 30),
#  ('Circulation', 30),
#  ('J Transp Health', 30),
#  ('Am Heart J', 30),
#  ('Diabetes Care', 30),
#  ('Scand J Trauma Resusc Emerg Med', 30),
#  ('Indian J Nephrol', 30),
#  ('Curr HIV/AIDS Rep', 30),
#  ('Technol Soc', 30),
#  ('J Neurovirol', 30),
#  ('Implement Sci', 30),
#  ('Nurse Lead', 30),
#  ('Subst Abuse Treat Prev Policy', 30),
#  ('Wirel Pers Commun', 30),
#  ('Prospects (Paris)', 30),
#  ('Open Heart', 30),
#  ('Infect Dis Clin Pract (Baltim Md)', 30),
#  ('Eat Weight Disord', 30),
#  ('Circ.Econ.Sust.', 30),
#  ('Rev Bras Ter Intensiva', 29),
#  ('Bull Math Biol', 29),
#  ('Arch Acad Emerg Med', 29),
#  ('Environ Int', 29),
#  ('Lancet Child Adolesc Health', 29),
#  ('Int Health', 29),
#  ('Case Rep Infect Dis', 29),
#  ('Radiol Cardiothorac Imaging', 29),
#  ('Can J Infect Dis Med Microbiol', 29),
#  ('Int J Hosp Manag', 29),
#  ('Ophthalmologe', 29),
#  ('ATS scholar', 29),
#  ('Trauma Surg Acute Care Open', 29),
#  ('Nurs Outlook', 29),
#  ('Oral Oncol', 29),
#  ('Psychosomatics', 29),
#  ('Inflamm Bowel Dis', 29),
#  ('Radiol Med', 29),
#  ('Med Educ', 29),
#  ('Drug Alcohol Rev', 29),
#  ('Stroke', 29),
#  ('Soc Sci Q', 29),
#  ('HRB Open Res', 29),
#  ('Transp Res Part A Policy Pract', 29),
#  ('Clin Transl Allergy', 29),
#  ('Nutrition', 29),
#  ('World Med Health Policy', 29),
#  ('Journal of biomolecular structure & dynamics', 29),
#  ('Ther Adv Infect Dis', 29),
#  ('Metabol Open', 29),
#  ('Am J Mens Health', 29),
#  ...]

# %%
selected = ['Int J Environ Res Public Health','Front Public Health','Br J Surg','Front Immunol','Int J Mol Sci','J Clin Med']

# %%
n_per_class = 197

# %%
samples = []
for jrnl in selected:
    df = papers.loc[papers['journal']==jrnl].sample(n=n_per_class, random_state=0)
    samples.append(df)
samples = pd.concat(samples,axis=0)

# %%
samples['label'] = list(map(lambda x:selected.index(x),samples['journal'].tolist()))

# %%
Y = samples['label']

# %%
models_scores = dict()
for method in ['TF-IDF','Glove','SciBert','Biobert']:
    # method = 'scibert'
    # method = 'tfidf'
    # SCIBERT Embedding
    if method == 'SciBert':
        print('SciBert')
        title_embs_df = pd.read_csv(f'scibert_encoded_papers/title_embs_df_{data_dir}.csv',index_col=0)
        abstract_embs_df = pd.read_csv(f'scibert_encoded_papers/abstract_embs_df_{data_dir}.csv',index_col=0)
        paper_emb = title_embs_df.join(abstract_embs_df,lsuffix='_ti',rsuffix='_ab')
        uid_map = {uid:i for i,uid in enumerate(title_embs_df.index)}
        X = paper_emb.values[list(map(lambda x:uid_map[x],samples.index.tolist()))]
    
    # SCIBERT Embedding
    if method == 'Biobert':
        print('Biobert')
        title_embs_df = pd.read_csv(f'title_embs_df_biobert_{data_dir}.csv',index_col=0)
        abstract_embs_df = pd.read_csv(f'abstract_embs_df_biobert_{data_dir}.csv',index_col=0)
        paper_emb = title_embs_df.join(abstract_embs_df,lsuffix='_ti',rsuffix='_ab')
        uid_map = {uid:i for i,uid in enumerate(title_embs_df.index)}
        X = paper_emb.values[list(map(lambda x:uid_map[x],samples.index.tolist()))]
    # Glove Embedding
    if method == 'Glove':
        print('Glove')
        title_embs_df = pd.read_csv(f'title_embs_df_glove_{data_dir}.csv',index_col=0)
        abstract_embs_df = pd.read_csv(f'abstract_embs_df_glove_{data_dir}.csv',index_col=0)
        paper_emb = title_embs_df.join(abstract_embs_df,lsuffix='_ti',rsuffix='_ab')
        uid_map = {uid:i for i,uid in enumerate(title_embs_df.index)}
        X = paper_emb.values[list(map(lambda x:uid_map[x],samples.index.tolist()))]


    # TF-IDF Embedding
    if method == 'TF-IDF':
        print('TF-IDF')
        values = scipy.sparse.load_npz(f'tf-idf-results/values_{data_dir}_scibert_token.npz')
        index = json.load(open(f"tf-idf-results/index_{data_dir}_scibert_token",'r',encoding='utf-8'))
        column = json.load(open(f"tf-idf-results/column_{data_dir}_scibert_token",'r',encoding='utf-8'))
        # paper_emb = pd.DataFrame.sparse.from_spmatrix(values,columns=column,index=index)
        uid_map = {uid:i for i,uid in enumerate(index)}
        X = values[list(map(lambda x:uid_map[x],samples.index.tolist()))]
    

    clf = RandomForestClassifier()
    models_scores[method] = cross_validate(clf, X, Y, cv=5,
                             scoring=('f1_micro', 'f1_macro','neg_log_loss'),
                             return_train_score=True)
# Out:
# TF-IDF
# Glove
# SciBert
# Biobert

# %%
data = []
for k,v in models_scores.items():
    for i in range(5):
        data.append([k,'Test Micro F1',v['test_f1_micro'][i]])
    for i in range(5):
        data.append([k,'Test Macro F1',v['test_f1_macro'][i]])
#     for i in range(5):
#         data.append([k,'test_neg_log_loss',v['test_neg_log_loss'][i]])

# %%
data_df = pd.DataFrame(data,columns=['method','metric','value'])

# %%
df = pd.concat([data_df.groupby(['method','metric']).apply(lambda x: x.mean()), data_df.groupby(['method','metric']).apply(lambda x: x.std())], axis=1)
# Out:
# C:\Users\袁伟康\AppData\Local\Temp\ipykernel_51472\154209075.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = pd.concat([data_df.groupby(['method','metric']).apply(lambda x: x.mean()), data_df.groupby(['method','metric']).apply(lambda x: x.std())], axis=1)
# C:\Users\袁伟康\AppData\Local\Temp\ipykernel_51472\154209075.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = pd.concat([data_df.groupby(['method','metric']).apply(lambda x: x.mean()), data_df.groupby(['method','metric']).apply(lambda x: x.std())], axis=1)

# %%
df.columns = ['Mean', 'Std']

# %%
df
# Out:
#                            Mean       Std
# method  metric
# Biobert Test Macro F1  0.685528  0.025661
#         Test Micro F1  0.688668  0.024496
# Glove   Test Macro F1  0.659188  0.031707
#         Test Micro F1  0.663245  0.031972
# SciBert Test Macro F1  0.687815  0.036320
#         Test Micro F1  0.692051  0.035012
# TF-IDF  Test Macro F1  0.642130  0.033261
#         Test Micro F1  0.650594  0.031404

# %%
df.round(4).to_excel('jrnl_clf.xlsx')

# %%
# iris_df = sns.load_dataset('iris')

# %%
# data_df

# %%
# iris_df

# %%
# Grouped violinplot
plt.figure(figsize=(8,5))
sns.boxplot(x='method', y='value',hue="metric", data=data_df, width=0.5, linewidth=1.,whis=8)
# sns.catplot(x='method', y='value',hue="metric", data=data_df, linewidth=1,height=4, aspect=.7, palette="Set3")
# sns.swarmplot(x='method', y='value',hue="metric", data=data_df,palette="Blues")

plt.legend(loc='upper left',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Metric Value',fontsize=16)
plt.xlabel('Method',fontsize=16)
# plt.show()
plt.tight_layout()
plt.savefig('Jrnl_Classification.png',dpi=300)

# %%
# scores

# %%
# print(scores['test_f1_micro'])
# print(scores['test_f1_macro'])
# print(scores['test_neg_log_loss'])
